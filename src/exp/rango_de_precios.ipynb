# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')

types = {'id': int, 'titulo': str, 'descripcion': str, 'tipodepropiedad': str, 'direccion': str,
        'ciudad': str, 'provincia': str, 'antiguedad': np.float32, 'habitaciones': np.float32,
        'garages':np.float32, 'idzona': np.float32, 'lat': np.float32, 'lng': np.float32,
        'gimnasio': bool, 'usosmultiples': bool, 'piscina': bool, 'escuelascercanas':bool,
        'centroscomercialescercanos':bool, 'precio':int}
pd.set_option('display.max_columns', 30)
data = pd.read_csv('../../data/train.csv', dtype = types)

data.head()
# Out:
#        id                                             titulo  \
# 0  254099                                  depto. tipo a-402
# 1   53461                     condominio horizontal en venta
# 2  247984              casa en venta urbi 3 recamaras tonala
# 3  209067  casa sola en toluca zinacantepec con credito i...
# 4  185997                                     paseos del sol
#
#                                          descripcion     tipodepropiedad  \
# 0  depto. interior de 80.15m2, consta de sala com...         Apartamento
# 1  <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 2  descripcion \nla mejor ubicacion residencial e...                Casa
# 3  casa en privada con caseta de vigilancia casas...                Casa
# 4  bonito departamento en excelentes condiciones ...         Apartamento
#
#                          direccion                  ciudad         provincia  \
# 0  Avenida Division del Norte 2005           Benito Juárez  Distrito Federal
# ...

# %%
propiedades_por_tipo = pd.DataFrame()
propiedades_por_tipo['tipodepropiedad'] = data['tipodepropiedad']
propiedades_por_tipo['precio_en_miles'] = data['precio']/1000
propiedades_por_tipo.head()
# Out:
#       tipodepropiedad  precio_en_miles
# 0         Apartamento           2273.0
# 1  Casa en condominio           3600.0
# 2                Casa           1200.0
# 3                Casa            650.0
# 4         Apartamento           1150.0

# %%
plt.figure(figsize=(16, 6))
ax = sns.boxplot(x = propiedades_por_tipo.tipodepropiedad, y = propiedades_por_tipo.precio_en_miles, width = 1,
           fliersize = 1)
plt.xticks(rotation=75)
plt.suptitle('Precio por tipo de propiedad', fontsize=18)
plt.xlabel("Tipo de Propiedad", fontsize = 14)
plt.ylabel("Precio promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio promedio (k$)')

# %%
propiedades_por_provincia = pd.DataFrame()
propiedades_por_provincia['provincia'] = data['provincia']
propiedades_por_provincia['precio_en_miles'] = data['precio']/1000
propiedades_por_provincia.head()
# Out:
#           provincia  precio_en_miles
# 0  Distrito Federal           2273.0
# 1  Distrito Federal           3600.0
# 2           Jalisco           1200.0
# 3    Edo. de México            650.0
# 4           Jalisco           1150.0

# %%
plt.figure(figsize=(16, 6))
ax = sns.boxplot(x = propiedades_por_provincia.provincia, y = propiedades_por_provincia.precio_en_miles, width = 1,
           fliersize = 1)
plt.xticks(rotation=75)
plt.suptitle('Precio de propiedad por provincia', fontsize=18)
plt.xlabel("Provincia", fontsize = 14)
plt.ylabel("Precio promedio de propiedad (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio promedio de propiedad (k$)')

# %%
propiedades_por_antiguedad = pd.DataFrame()
propiedades_por_antiguedad['antiguedad'] = data['antiguedad']
propiedades_por_antiguedad['precio_en_miles'] = data['precio']/1000
propiedades_por_antiguedad.head()
# Out:
#    antiguedad  precio_en_miles
# 0         NaN           2273.0
# 1        10.0           3600.0
# 2         5.0           1200.0
# 3         1.0            650.0
# 4        10.0           1150.0

# %%
plt.figure(figsize=(16, 6))
ax = sns.boxplot(x = propiedades_por_antiguedad.antiguedad, y = propiedades_por_antiguedad.precio_en_miles, width = 1,
           fliersize = 1)
plt.xticks(rotation=75)
plt.suptitle('Precio por antiguedad', fontsize=18)
plt.xlabel("Antiguedad de la propiedad", fontsize = 14)
plt.ylabel("Precio promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio promedio (k$)')

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(x = propiedades_por_antiguedad.antiguedad, y = propiedades_por_antiguedad.precio_en_miles)
plt.xticks(rotation=75)
plt.suptitle('Precio por antiguedad', fontsize=18)
plt.xlabel("Antiguedad de la propiedad", fontsize = 14)
plt.ylabel("Precio promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio promedio (k$)')

# %%
propiedades_por_habitaciones = pd.DataFrame()
propiedades_por_habitaciones['habitaciones'] = data['habitaciones']
propiedades_por_habitaciones['precio_en_miles'] = data['precio']/1000
propiedades_por_habitaciones.head()
# Out:
#    habitaciones  precio_en_miles
# 0           2.0           2273.0
# 1           3.0           3600.0
# 2           3.0           1200.0
# 3           2.0            650.0
# 4           2.0           1150.0

# %%
plt.figure(figsize=(8, 4))
ax = sns.boxplot(x = propiedades_por_habitaciones.habitaciones, y = propiedades_por_habitaciones.precio_en_miles, width = 1,
           fliersize = 1, palette = "Blues")
plt.xticks(rotation=75)
plt.suptitle('Precio por numero de habitaciones', fontsize=18)
plt.xlabel("Numero de habitaciones de la propiedad", fontsize = 14)
plt.ylabel("Precio promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio promedio (k$)')

# %%
propiedades_por_anio = pd.DataFrame()
propiedades_por_anio['anio_de_publicacion'] = pd.to_datetime(data['fecha']).apply(lambda x: x.year)
propiedades_por_anio['precio_en_miles'] = data['precio']/1000
propiedades_por_anio.head()
# Out:
#    anio_de_publicacion  precio_en_miles
# 0                 2015           2273.0
# 1                 2013           3600.0
# 2                 2015           1200.0
# 3                 2012            650.0
# 4                 2016           1150.0

# %%
plt.figure(figsize=(4, 7))
ax = sns.boxplot(x = propiedades_por_anio.anio_de_publicacion, y = propiedades_por_anio.precio_en_miles, width = 1,
           fliersize = 1, palette = "Blues")
plt.suptitle('Precio por anio de publicacion', fontsize=18)
plt.xlabel("Anio de publicacion", fontsize = 14)
plt.ylabel("Precio propiedad promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio propiedad promedio (k$)')

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(x = propiedades_por_anio.anio_de_publicacion, y = propiedades_por_anio.precio_en_miles)
plt.suptitle('Precio por anio de publicacion', fontsize=18)
plt.xticks(np.arange(2012, 2017, step=1))
plt.xlabel("Anio de publicacion", fontsize = 14)
plt.ylabel("Precio propiedad promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio propiedad promedio (k$)')

# %%
propiedades_por_mes = pd.DataFrame()
propiedades_por_mes['mes_de_publicacion'] = pd.to_datetime(data['fecha']).apply(lambda x: x.month)
propiedades_por_mes['precio_en_miles'] = data['precio']/1000
propiedades_por_mes.head()
# Out:
#    mes_de_publicacion  precio_en_miles
# 0                   8           2273.0
# 1                   6           3600.0
# 2                  10           1200.0
# 3                   3            650.0
# 4                   6           1150.0

# %%
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

plt.figure(figsize=(8, 7))
ax = sns.boxplot(x = propiedades_por_mes.mes_de_publicacion, y = propiedades_por_mes.precio_en_miles, width = 1,
           fliersize = 1)
plt.xticks()
plt.suptitle('Precio por mes de publicacion', fontsize=18)
plt.xlabel("Mes de publicacion", fontsize = 14)
plt.ylabel("Precio propiedad promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio propiedad promedio (k$)')

# %%
propiedades_por_superficie = pd.DataFrame()
propiedades_por_superficie['metroscubiertos'] = data['metroscubiertos']
propiedades_por_superficie['metrostotales'] = data['metrostotales']
propiedades_por_superficie['precio_en_miles'] = data['precio']/1000
propiedades_por_superficie.head()
# Out:
#    metroscubiertos  metrostotales  precio_en_miles
# 0             80.0           80.0           2273.0
# 1            268.0          180.0           3600.0
# 2            144.0          166.0           1200.0
# 3             63.0           67.0            650.0
# 4             95.0           95.0           1150.0

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(x = 'metroscubiertos', y = 'precio_en_miles', data = propiedades_por_superficie, label='Metros cubiertos')
ax = sns.lineplot(x = 'metrostotales', y = 'precio_en_miles', data=propiedades_por_superficie, label = 'Metros totales')
plt.suptitle('Precio por superficie', fontsize=18)
plt.xlabel("Superficie", fontsize = 14)
plt.ylabel("Precio propiedad promedio (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio propiedad promedio (k$)')

# %%
propiedades_por_superficie_de_habitacion = pd.DataFrame()
propiedades_por_superficie_de_habitacion['superficie_habitacion_promedio'] = data['metroscubiertos']/data['habitaciones']
propiedades_por_superficie_de_habitacion['precio_en_miles'] = data['precio']/1000
propiedades_por_superficie_de_habitacion.head()
# Out:
#    superficie_habitacion_promedio  precio_en_miles
# 0                       40.000000           2273.0
# 1                       89.333333           3600.0
# 2                       48.000000           1200.0
# 3                       31.500000            650.0
# 4                       47.500000           1150.0

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(x = 'superficie_habitacion_promedio', y = 'precio_en_miles', data = propiedades_por_superficie_de_habitacion)
plt.suptitle('Precio por superficie/habitaciones', fontsize=18)
plt.xlabel("Superficie/# de habitaciones", fontsize = 14)
plt.ylabel("Precio propiedad (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio propiedad (k$)')

# %%
casas = pd.DataFrame()
casas['precio_en_miles'] = data['precio']/1000
casas['metroscubiertos'] = data['metroscubiertos']
casas['tipodepropiedad'] = data['tipodepropiedad']
casas['antiguedad'] = data['antiguedad']
casas = casas.loc[casas.tipodepropiedad == 'Casa']
casas.drop(['tipodepropiedad'], axis=1, inplace = True)

apartamentos = pd.DataFrame()
apartamentos['precio_en_miles'] = data['precio']/1000
apartamentos['metroscubiertos'] = data['metroscubiertos']
apartamentos['tipodepropiedad'] = data['tipodepropiedad']
apartamentos['antiguedad'] = data['antiguedad']
apartamentos = apartamentos.loc[apartamentos.tipodepropiedad == 'Apartamento']
apartamentos.drop(['tipodepropiedad'], axis=1, inplace = True)
apartamentos.head()
# Out:
#     precio_en_miles  metroscubiertos  antiguedad
# 0            2273.0             80.0         NaN
# 4            1150.0             95.0        10.0
# 5            1100.0             75.0         5.0
# 8             310.0             58.0         1.0
# 11           7200.0            256.0         NaN

# %%
plt.figure(figsize=(12, 6))
ax = sns.scatterplot(x = 'metroscubiertos', y = 'precio_en_miles', data = casas, alpha = 0.25, label = 'Casas')
ax = sns.scatterplot(x = 'metroscubiertos', y = 'precio_en_miles', data = apartamentos, alpha = 0.25, label = 'Apartamentos')
plt.suptitle('Precio por superficie: Casas vs. Apartamentos', fontsize=18)
plt.xlabel("Superficie", fontsize = 14)
plt.ylabel("Precio propiedad (k$)", fontsize = 14)
# Out:
# Text(0, 0.5, 'Precio propiedad (k$)')
