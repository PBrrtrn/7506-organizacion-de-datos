# %%
import pandas as pd
import numpy as np

types = {'id': int, 'titulo': str, 'descripcion': str, 'tipodepropiedad': str, 'direccion': str,
        'ciudad': str, 'provincia': str, 'antiguedad': np.float32, 'habitaciones': np.float32,
        'garages':np.float32, 'idzona': np.float32, 'lat': np.float32, 'lng': np.float32,
        'gimnasio': int, 'usosmultiples': int, 'piscina': int, 'escuelascercanas': int,
        'centroscomercialescercanos': int, 'precio':int}

non_numerical_types = ['titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad', 'provincia', 'lat', 'lng','idzona']

pd.set_option('display.max_columns', 30)

training_data = pd.read_csv('../../data/TP2/train.csv', dtype = types, \
                            usecols=['id', 'metroscubiertos', 'metrostotales', 'tipodepropiedad','ciudad', 'habitaciones'])
test_data = pd.read_csv('../../data/TP2/test.csv', dtype = types, \
                            usecols=['id', 'metroscubiertos', 'metrostotales', 'tipodepropiedad','ciudad', 'habitaciones'])
training_data.head()
# Out:
# /home/mati/.local/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /home/mati/.local/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#        id     tipodepropiedad                  ciudad  habitaciones  \
# 0  254099         Apartamento           Benito Juárez           2.0
# 1   53461  Casa en condominio  La Magdalena Contreras           3.0
# 2  247984                Casa                  Tonalá           3.0
# 3  209067                Casa            Zinacantepec           2.0
# 4  185997         Apartamento                 Zapopan           2.0
#
#    metroscubiertos  metrostotales
# 0             80.0           80.0
# ...

# %%
por_ciudadt = training_data.groupby('ciudad').agg(metros_avg_cubiertos_ciudad = ('metroscubiertos','mean'),\
                                                 metros_avg_ciudad = ('metrostotales','mean'), habitaciones_avg_ciudad = ('habitaciones','mean')).reset_index()

por_ciudad_ev = test_data.groupby('ciudad').agg(metros_avg_cubiertos_ciudad = ('metroscubiertos','mean'),\
                                                 metros_avg_ciudad = ('metrostotales','mean'), habitaciones_avg_ciudad = ('habitaciones','mean')).reset_index()
por_ciudadt.head(20)
# Out:
#                 ciudad  metros_avg_cubiertos_ciudad  metros_avg_ciudad  \
# 0                Abalá                          NaN         200.000000
# 1              Abasolo                   231.666667         287.833333
# 2             Abejones                   200.000000                NaN
# 3              Acajete                   245.333333         196.333333
# 4              Acambay                   147.125000         186.600000
# 5            Acaponeta                          NaN         380.000000
# 6   Acapulco de Juárez                   157.145058         168.980361
# 7              Acateno                   107.000000                NaN
# 8               Acatic                   176.000000                NaN
# 9            Acatzingo                   211.000000         211.000000
# 10            Acayucan                    65.000000          68.000000
# 11             Acolman                   105.144928         108.777778
# ...

# %%
por_ciudad_y_tipot = training_data.groupby(['ciudad','tipodepropiedad']).agg(metros_avg_cub_ciudad_tipo = ('metroscubiertos','mean'),\
                                                 metros_avg_ciudad_tipo = ('metrostotales','mean'), habitaciones_avg_ciudad_tipo = ('habitaciones','mean')).reset_index()

por_ciudad_y_tipo_ev = test_data.groupby(['ciudad','tipodepropiedad']).agg(metros_avg_cub_ciudad_tipo = ('metroscubiertos','mean'),\
                                                 metros_avg_ciudad_tipo = ('metrostotales','mean'), habitaciones_avg_ciudad_tipo = ('habitaciones','mean')).reset_index()

por_ciudad_y_tipot.head(10)
# Out:
#      ciudad    tipodepropiedad  metros_avg_cub_ciudad_tipo  \
# 0     Abalá            Terreno                         NaN
# 1   Abasolo               Casa                  288.000000
# 2   Abasolo  Casa uso de suelo                  119.000000
# 3  Abejones               Casa                  200.000000
# 4   Acajete        Apartamento                   82.000000
# 5   Acajete               Casa                  278.000000
# 6   Acajete            Terreno                         NaN
# 7   Acambay        Apartamento                   54.000000
# 8   Acambay               Casa                  163.166667
# 9   Acambay  Terreno comercial                  144.000000
#
#    metros_avg_ciudad_tipo  habitaciones_avg_ciudad_tipo
# 0                   200.0                           NaN
# 1                   360.0                          2.75
# 2                   143.5                          6.50
# 3                     NaN                          3.00
# ...

# %%
ciudad_tipo_train = training_data.merge(por_ciudad_y_tipot, on = ['ciudad','tipodepropiedad'])
ciudad_tipo_test = test_data.merge(por_ciudad_y_tipo_ev, on = ['ciudad','tipodepropiedad'])
ciudad_tipo_train.head()
# Out:
#        id tipodepropiedad         ciudad  habitaciones  metroscubiertos  \
# 0  254099     Apartamento  Benito Juárez           2.0             80.0
# 1   73348     Apartamento  Benito Juárez           3.0            127.0
# 2  244353     Apartamento  Benito Juárez           2.0             98.0
# 3  237577     Apartamento  Benito Juárez           3.0            160.0
# 4  200567     Apartamento  Benito Juárez           2.0            122.0
#
#    metrostotales  metros_avg_cub_ciudad_tipo  metros_avg_ciudad_tipo  \
# 0           80.0                  104.114775              110.943868
# 1          127.0                  104.114775              110.943868
# 2            NaN                  104.114775              110.943868
# 3            NaN                  104.114775              110.943868
# 4          122.0                  104.114775              110.943868
#
#    habitaciones_avg_ciudad_tipo
# 0                      2.350425
# 1                      2.350425
# ...

# %%
ciudad_train = training_data.merge(por_ciudadt, on = ['ciudad'])
ciudad_test = test_data.merge(por_ciudad_ev, on = ['ciudad'])
ciudad_test.head()
# Out:
#        id tipodepropiedad          ciudad  habitaciones  metroscubiertos  \
# 0    4941            Casa  Miguel Hidalgo           3.0            300.0
# 1  272001            Casa  Miguel Hidalgo           3.0            220.0
# 2  201853     Apartamento  Miguel Hidalgo           2.0             67.0
# 3  112778     Apartamento  Miguel Hidalgo           2.0             78.0
# 4  212520     Apartamento  Miguel Hidalgo           3.0            118.0
#
#    metrostotales  metros_avg_cubiertos_ciudad  metros_avg_ciudad  \
# 0            NaN                   146.782769         154.326116
# 1          196.0                   146.782769         154.326116
# 2           67.0                   146.782769         154.326116
# 3           78.0                   146.782769         154.326116
# 4          118.0                   146.782769         154.326116
#
#    habitaciones_avg_ciudad
# 0                 2.504227
# 1                 2.504227
# 2                 2.504227
# ...

# %%
ciudad_train.drop(columns=['metrostotales','metroscubiertos','habitaciones','ciudad','tipodepropiedad'],inplace=True)
ciudad_test.drop(columns=['metrostotales','metroscubiertos','habitaciones','ciudad','tipodepropiedad'],inplace=True)
ciudad_tipo_train.drop(columns=['metrostotales','metroscubiertos','habitaciones','ciudad','tipodepropiedad'],inplace=True)
ciudad_tipo_test.drop(columns=['metrostotales','metroscubiertos','habitaciones','ciudad','tipodepropiedad'],inplace=True)
ciudad_train.head()
# Out:
#        id  metros_avg_cubiertos_ciudad  metros_avg_ciudad  \
# 0  254099                   126.665194         138.116722
# 1  130216                   126.665194         138.116722
# 2   73348                   126.665194         138.116722
# 3  244353                   126.665194         138.116722
# 4  237577                   126.665194         138.116722
#
#    habitaciones_avg_ciudad
# 0                  2.53504
# 1                  2.53504
# 2                  2.53504
# 3                  2.53504
# 4                  2.53504

# %%
ciudad_tipo_train.head()
# Out:
#        id  metros_avg_cub_ciudad_tipo  metros_avg_ciudad_tipo  \
# 0  254099                  104.114775              110.943868
# 1   73348                  104.114775              110.943868
# 2  244353                  104.114775              110.943868
# 3  237577                  104.114775              110.943868
# 4  200567                  104.114775              110.943868
#
#    habitaciones_avg_ciudad_tipo
# 0                      2.350425
# 1                      2.350425
# 2                      2.350425
# 3                      2.350425
# 4                      2.350425

# %%
ciudad_tipo_train.to_csv('../../res/ftr/promedios_ciudad_tipo_train.csv')
ciudad_tipo_test.to_csv('../../res/ftr/promedios_ciudad_tipo_evaluation.csv')

# %%
ciudad_train.to_csv('../../res/ftr/promedios_ciudad_train.csv')
ciudad_test.to_csv('../../res/ftr/promedios_ciudad_evaluation.csv')
